// %% [markdown]
// # Lab 17 Exercise 1

// %% [markdown]
// ## Interface

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab17_Ex01
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// var animal_1 = new Dog();
// animal_1.Move();
//
// IMovable animal_2 = new Dog();
// animal_2.Move();
//
// interface IMovable
// {
//     public void Move();
// }
//
// abstract class Animal : IMovable
// {
//     abstract public void Move();
// }
// class Dog : Animal
// {
//     public override void Move()
//     {
//         System.Console.WriteLine("Dog move by running on the ground");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab17_Ex01
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab17_Ex01
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ใช้ interface และ abstract class ในการออกแบบโครงสร้างโปรแกรมทำให้รองรับ polymorphism และสามารถสร้าง object ที่ถูกเรียกใช้ผ่านชนิดของ interface ได้
